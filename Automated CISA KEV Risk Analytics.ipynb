# %% [markdown]
# <a href="https://colab.research.google.com/github/meinicharat/Automated-CISA-KEV-Risk-Analytics/blob/main/Cyber_and_IT_risk_analytics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install pandas sqlalchemy sqlite-utils altair python-dateutil

# %%
import sys, os, math
import pandas as pd
import sqlalchemy as sa
import sqlite3
import altair as alt
import numpy as np

# %%
os.makedirs("exports", exist_ok=True)

# %%
print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("SQLAlchemy:", sa.__version__)
print("sqlite3 (client):", sqlite3.sqlite_version)
print("Altair:", alt.__version__)
# Out:
# Python: 3.12.12
# pandas: 2.2.2
# SQLAlchemy: 2.0.44
# sqlite3 (client): 3.37.2
# Altair: 5.5.0

# %%
try:
    con = sqlite3.connect(":memory:")
    cur = con.cursor()
    cur.execute("PRAGMA compile_options;")
    opts = [r[0] for r in cur.fetchall()]
    con.close()
    print("SQLite compile options:")
    for o in opts[:10]:
        print(" -", o)
except Exception as e:
    print("ตรวจ PRAGMA ไม่สำเร็จ:", e)

print("\n[SUMMARY] Environment is ready. Created folder: ./exports")
# Out:
# SQLite compile options:
#  - ATOMIC_INTRINSICS=1
#  - COMPILER=gcc-11.4.0
#  - DEFAULT_AUTOVACUUM
#  - DEFAULT_CACHE_SIZE=-2000
#  - DEFAULT_FILE_FORMAT=4
#  - DEFAULT_JOURNAL_SIZE_LIMIT=-1
#  - DEFAULT_MMAP_SIZE=0
#  - DEFAULT_PAGE_SIZE=4096
#  - DEFAULT_PCACHE_INITSZ=20
#  - DEFAULT_RECURSIVE_TRIGGERS
#
# [SUMMARY] Environment is ready. Created folder: ./exports

# %%
url = "https://www.cisa.gov/sites/default/files/csv/known_exploited_vulnerabilities.csv"
df_raw = pd.read_csv(url, low_memory=False)

# %%
print("[RAW] Shape:", df_raw.shape)
print("[RAW] Total columns:", len(df_raw.columns))
print("[RAW] Columns (all):")
print(" | ".join(df_raw.columns.tolist()))
# Out:
# [RAW] Shape: (1478, 11)
# [RAW] Total columns: 11
# [RAW] Columns (all):
# cveID | vendorProject | product | vulnerabilityName | dateAdded | shortDescription | requiredAction | dueDate | knownRansomwareCampaignUse | notes | cwes

# %%
rename_map = {
    "cveID": "cve_id",
    "vendorProject": "vendor",
    "product": "product",
    "vulnerabilityName": "vuln_name",
    "dateAdded": "date_added",
    "shortDescription": "short_desc",
    "requiredAction": "required_action",
    "dueDate": "due_date",
    "knownRansomwareCampaignUse": "known_ransomware_use",
    "notes": "notes",
    "cwe": "cwe",
    "cwes": "cwe",
    "vulnerabilityDescription": "vuln_desc",
    "cvss": "cvss",
}

raw_cols = set(df_raw.columns)
present_to_rename = {k: v for k, v in rename_map.items() if k in raw_cols}
df = df_raw.rename(columns=present_to_rename)

# %%
for col in ["date_added", "due_date"]:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce", utc=True)

# %%
for col in ["cve_id", "vendor", "product", "vuln_name"]:
    if col in df.columns:
        df[col] = (
            df[col].astype(str)
                  .str.strip()
                  .str.replace(r"\s+", " ", regex=True)
                  )

# %%
for rc in ["cve_id", "date_added"]:
    if rc not in df.columns:
        df[rc] = np.nan
before_dropna = len(df)
df = df.dropna(subset=["cve_id", "date_added"])
after_dropna = len(df)

# %%
before_dedup = len(df)
df = df.drop_duplicates(subset=["cve_id", "vendor", "product", "date_added"]).reset_index(drop=True)
after_dedup = len(df)

# %%
#เอาไว้ดูรายเดือนได้
df["month_key"] = df["date_added"].dt.strftime("%Y-%m")

# %%
#summary
date_min = df["date_added"].min()
date_max = df["date_added"].max()
n_vendor = df["vendor"].nunique() if "vendor" in df.columns else None

# %%
print("[CLEAN] Rows after dropna:", after_dropna, f"(removed {before_dropna - after_dropna})")
print("[CLEAN] Rows after dedupe:", after_dedup, f"(removed {before_dedup - after_dedup})")
print(f"[CLEAN] Date range: {date_min} -> {date_max}")
print(f"[CLEAN] Unique vendors: {n_vendor}")
print("\nSample rows:")
print(df[["cve_id","vendor","product","date_added","month_key"]].head(8).to_string(index=False))
# Out:
# [CLEAN] Rows after dropna: 1478 (removed 0)
# [CLEAN] Rows after dedupe: 1478 (removed 0)
# [CLEAN] Date range: 2021-11-03 00:00:00+00:00 -> 2025-12-16 00:00:00+00:00
# [CLEAN] Unique vendors: 242
#
# Sample rows:
#         cve_id          vendor                 product                date_added month_key
# CVE-2025-59718        Fortinet       Multiple Products 2025-12-16 00:00:00+00:00   2025-12
# CVE-2025-14611        Gladinet CentreStack and Triofox 2025-12-15 00:00:00+00:00   2025-12
# CVE-2025-43529           Apple       Multiple Products 2025-12-15 00:00:00+00:00   2025-12
#  CVE-2018-4063 Sierra Wireless           AirLink ALEOS 2025-12-12 00:00:00+00:00   2025-12
# CVE-2025-14174          Google                Chromium 2025-12-12 00:00:00+00:00   2025-12
# CVE-2025-58360           OSGeo               GeoServer 2025-12-11 00:00:00+00:00   2025-12
#  CVE-2025-6218          RARLAB                  WinRAR 2025-12-09 00:00:00+00:00   2025-12
# CVE-2025-62221       Microsoft                 Windows 2025-12-09 00:00:00+00:00   2025-12

# %%
missing_pct = df.isna().mean().sort_values(ascending=False) * 100
print("\n[Missing % Top 8]\n", missing_pct.head(8).round(2).to_string())
# Out:
# [Missing % Top 8]
#  cwe                11.23
# cve_id              0.00
# product             0.00
# vendor              0.00
# vuln_name           0.00
# date_added          0.00
# required_action     0.00
# short_desc          0.00

# %%
print(df.shape)
# Out:
# (1478, 12)

# %%
df[df["cwe"].isna()]
# Out:
#               cve_id       vendor  \
# 4     CVE-2025-14174       Google
# 10    CVE-2025-55182         Meta
# 12    CVE-2025-48633      Android
# 13    CVE-2025-48572      Android
# 32    CVE-2022-48503        Apple
# ...              ...          ...
# 1430  CVE-2019-16256  SIMalliance
# 1451   CVE-2020-8467  Trend Micro
# 1453  CVE-2020-24557  Trend Micro
# 1454   CVE-2020-8599  Trend Micro
# 1459   CVE-2020-5847       Unraid
#
#                                                 product  \
# 4                                              Chromium
# 10                              React Server Components
# 12                                            Framework
# 13                                            Framework
# 32                                    Multiple Products
# ...                                                 ...
# 1430                                    Toolbox Browser
# 1451                            Apex One and OfficeScan
# 1453  Apex One, OfficeScan, and Worry-Free Business ...
# 1454                            Apex One and OfficeScan
# 1459                                             Unraid
#
#                                               vuln_name  \
# 4     Google Chromium Out of Bounds Memory Access Vu...
# 10    Meta React Server Components Remote Code Execu...
# 12    Android Framework Information Disclosure Vulne...
# 13    Android Framework Privilege Escalation Vulnera...
# 32    Apple Multiple Products Unspecified Vulnerability
# ...                                                 ...
# 1430  SIMalliance Toolbox Browser Command Injection ...
# 1451  Trend Micro Apex One and OfficeScan Remote Cod...
# 1453  Trend Micro Multiple Products Improper Access ...
# 1454  Trend Micro Apex One and OfficeScan Authentica...
# 1459         Unraid Remote Code Execution Vulnerability
#
#                     date_added  \
# 4    2025-12-12 00:00:00+00:00
# 10   2025-12-05 00:00:00+00:00
# 12   2025-12-02 00:00:00+00:00
# 13   2025-12-02 00:00:00+00:00
# 32   2025-10-20 00:00:00+00:00
# ...                        ...
# 1430 2021-11-03 00:00:00+00:00
# 1451 2021-11-03 00:00:00+00:00
# 1453 2021-11-03 00:00:00+00:00
# 1454 2021-11-03 00:00:00+00:00
# 1459 2021-11-03 00:00:00+00:00
#
#                                              short_desc  \
# 4     Google Chromium contains an out of bounds memo...
# 10    Meta React Server Components contains a remote...
# 12    Android Framework contains an unspecified vuln...
# 13    Android Framework contains an unspecified vuln...
# 32    Apple macOS, iOS, tvOS, Safari, and watchOS co...
# ...                                                 ...
# 1430  SIMalliance Toolbox Browser contains an comman...
# 1451  Trend Micro Apex One and OfficeScan contain an...
# 1453  Trend Micro Apex One, OfficeScan, and Worry-Fr...
# 1454  Trend Micro Apex One and OfficeScan server con...
# 1459  Unraid contains a vulnerability due to the ins...
#
#                                         required_action  \
# 4     Apply mitigations per vendor instructions, fol...
# 10    Apply mitigations per vendor instructions, fol...
# 12    Apply mitigations per vendor instructions, fol...
# 13    Apply mitigations per vendor instructions, fol...
# 32    Apply mitigations per vendor instructions, fol...
# ...                                                 ...
# 1430             Apply updates per vendor instructions.
# 1451             Apply updates per vendor instructions.
# 1453             Apply updates per vendor instructions.
# 1454             Apply updates per vendor instructions.
# 1459             Apply updates per vendor instructions.
#
#                       due_date known_ransomware_use  \
# 4    2026-01-02 00:00:00+00:00              Unknown
# 10   2025-12-12 00:00:00+00:00                Known
# 12   2025-12-23 00:00:00+00:00              Unknown
# 13   2025-12-23 00:00:00+00:00              Unknown
# 32   2025-11-10 00:00:00+00:00              Unknown
# ...                        ...                  ...
# 1430 2022-05-03 00:00:00+00:00              Unknown
# 1451 2022-05-03 00:00:00+00:00              Unknown
# 1453 2022-05-03 00:00:00+00:00              Unknown
# 1454 2022-05-03 00:00:00+00:00              Unknown
# 1459 2022-05-03 00:00:00+00:00              Unknown
#
#                                                   notes  cwe month_key
# 4     https://chromereleases.googleblog.com/2025/12/...  NaN   2025-12
# 10    Check for signs of potential compromise on all...  NaN   2025-12
# 12    https://source.android.com/docs/security/bulle...  NaN   2025-12
# 13    https://source.android.com/docs/security/bulle...  NaN   2025-12
# 32    https://support.apple.com/en-us/HT213340 ; htt...  NaN   2025-10
# ...                                                 ...  ...       ...
# 1430    https://nvd.nist.gov/vuln/detail/CVE-2019-16256  NaN   2021-11
# 1451     https://nvd.nist.gov/vuln/detail/CVE-2020-8467  NaN   2021-11
# 1453    https://nvd.nist.gov/vuln/detail/CVE-2020-24557  NaN   2021-11
# 1454     https://nvd.nist.gov/vuln/detail/CVE-2020-8599  NaN   2021-11
# 1459     https://nvd.nist.gov/vuln/detail/CVE-2020-5847  NaN   2021-11
#
# [166 rows x 12 columns]

# %%
df["cwe"].isna().sum()
# Out:
# np.int64(166)

# %%
df["cwe"].fillna("Unknown")
# Out:
# 0       CWE-347
# 1       CWE-798
# 2       CWE-416
# 3       CWE-434
# 4       Unknown
#          ...
# 1473     CWE-78
# 1474     CWE-55
# 1475    CWE-502
# 1476    CWE-434
# 1477    CWE-522
# Name: cwe, Length: 1478, dtype: object

# %%
df["cwe"] = df["cwe"].fillna("Unknown")

# %%
df["cwe"].isna().sum()
# Out:
# np.int64(0)

# %%
#EDA
import matplotlib.pyplot as plt

# %%
#ตรวจหา missing value
missing_pct = df.isna().mean().sort_values(ascending=False) * 100
print("Missing Values (%):")
print(missing_pct.round(2).to_string())
print("="*80)
# Out:
# Missing Values (%):
# cve_id                  0.0
# vendor                  0.0
# product                 0.0
# vuln_name               0.0
# date_added              0.0
# short_desc              0.0
# required_action         0.0
# due_date                0.0
# known_ransomware_use    0.0
# notes                   0.0
# cwe                     0.0
# month_key               0.0
# ================================================================================

# %%
#ตรวจ duplicates
dupes = df.duplicated(subset=["cve_id", "vendor", "product", "date_added"]).sum()
print(f"Duplicate rows (by cve_id + vendor + product + date_added): {dupes}")
# Out:
# Duplicate rows (by cve_id + vendor + product + date_added): 0

# %%
#trend ช่องโหว่รายเดือน
monthly_trend = df.groupby("month_key")["cve_id"].nunique().reset_index()
monthly_trend.rename(columns={"cve_id": "vuln_count"}, inplace=True)
print("Monthly Trend (Top 10 rows):")
print(monthly_trend.head(10).to_string(index=False))
# Out:
# Monthly Trend (Top 10 rows):
# month_key  vuln_count
#   2021-11         291
#   2021-12          20
#   2022-01          40
#   2022-02          32
#   2022-03         226
#   2022-04          45
#   2022-05          83
#   2022-06          48
#   2022-07           3
#   2022-08          23

# %%
#top 10 vendors
if "vendor" in df.columns:
    top_vendors = df["vendor"].value_counts().head(10).reset_index()
    top_vendors.columns = ["vendor", "vuln_count"]

    print("Top 10 Vendors:")
    print(top_vendors.to_string(index=False))
else:
    print("Column 'vendor' not found")
# Out:
# Top 10 Vendors:
#    vendor  vuln_count
# Microsoft         350
#     Apple          86
#     Cisco          81
#     Adobe          76
#    Google          67
#    Oracle          42
#    Apache          38
#    Ivanti          30
#    VMware          26
#    D-Link          25

# %%
#visualization
plt.figure(figsize=(10,5))
plt.plot(monthly_trend["month_key"], monthly_trend["vuln_count"], marker="o")
plt.xticks(rotation=60)
plt.title("Monthly Vulnerability Trend (CISA KEV)")
plt.xlabel("Month")
plt.ylabel("Number of Vulnerabilities (Unique CVE)")
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,4))
plt.bar(top_vendors["vendor"], top_vendors["vuln_count"])
plt.xticks(rotation=45, ha='right')
plt.title("Top 10 Vendors with the Most Vulnerabilities")
plt.ylabel("Number of Vulnerabilities")
plt.xlabel("Vendor")
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, text

db_path = "risk.db"
engine = create_engine(f"sqlite:///{db_path}", future=True)

# %%
#เตรียมdf
df_to_db = df.copy()

for col in ["date_added", "due_date"]:
    if col in df_to_db.columns:
        df_to_db[col] = pd.to_datetime(df_to_db[col], errors="coerce", utc=True).dt.strftime("%Y-%m-%d")

# %%
#เอาdfเก็บในsqlite
df_to_db.to_sql("kev_vulns", con=engine, if_exists="replace", index=False)
# Out:
# 1478

# %%
with engine.begin() as conn:
    conn.exec_driver_sql("CREATE INDEX IF NOT EXISTS idx_kev_date ON kev_vulns(date_added);")
    if "vendor" in df_to_db.columns:
        conn.exec_driver_sql("CREATE INDEX IF NOT EXISTS idx_kev_vendor ON kev_vulns(vendor);")

# %%
#ตรวจ risk.db
with engine.connect() as conn:
    rowcount = conn.execute(text("SELECT COUNT(*) FROM kev_vulns")).scalar_one()
    sample = pd.read_sql(text("""
        SELECT cve_id, vendor, product, date_added
        FROM kev_vulns
        ORDER BY date_added DESC
        LIMIT 5;
    """), conn)

# %%
#สรุปผล
print(f"เขียนตาราง kev_vulns ลง db '{db_path}' เรียบร้อย: {rowcount:,} แถว")
print("ตัวอย่าง 5 แถวล่าสุด:")
print(sample.to_string(index=False))
print("\n[SUMMARY] DB file exists:", os.path.exists(db_path), "| Size (bytes):", os.path.getsize(db_path) if os.path.exists(db_path) else 0)
# Out:
# เขียนตาราง kev_vulns ลง db 'risk.db' เรียบร้อย: 1,478 แถว
# ตัวอย่าง 5 แถวล่าสุด:
#         cve_id          vendor                 product date_added
# CVE-2025-59718        Fortinet       Multiple Products 2025-12-16
# CVE-2025-43529           Apple       Multiple Products 2025-12-15
# CVE-2025-14611        Gladinet CentreStack and Triofox 2025-12-15
# CVE-2025-14174          Google                Chromium 2025-12-12
#  CVE-2018-4063 Sierra Wireless           AirLink ALEOS 2025-12-12
#
# [SUMMARY] DB file exists: True | Size (bytes): 921600

# %%
import os
import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, text

# %%
#checkว่าเชื่อม db ยัง
db_path = "risk.db"
engine = create_engine(f"sqlite:///{db_path}", future=True)

assert os.path.exists(db_path), "ไม่พบ risk.db"

# %%
#query monthly trend + rolling 6 m
q_trend_rolling = """
WITH m AS (
  SELECT
    month_key,
    COUNT(DISTINCT cve_id) AS vuln_count
  FROM kev_vulns
  WHERE month_key IS NOT NULL
  GROUP BY month_key
)
SELECT
  month_key,
  vuln_count,
  SUM(vuln_count) OVER (
    ORDER BY month_key
    ROWS BETWEEN 5 PRECEDING AND CURRENT ROW
  ) AS rolling_6m
FROM m
ORDER BY month_key;
"""

# %%
#query monthly trend with vendor
q_trend_by_vendor = """
WITH m AS (
  SELECT
    month_key,
    vendor,
    COUNT(DISTINCT cve_id) AS vuln_count
  FROM kev_vulns
  WHERE month_key IS NOT NULL
  GROUP BY month_key, vendor
)
SELECT * FROM m
ORDER BY month_key, vendor;
"""

# %%
#Top vendors in the last 12 m
q_top_vendor_12m = """
WITH bounds AS (
  SELECT
    date(strftime('%Y-%m-01', MAX(date_added))) AS max_month_start,
    date(strftime('%Y-%m-01', MAX(date_added)), '-11 months') AS cutoff_month_start
  FROM kev_vulns
),
filtered AS (
  SELECT k.vendor, k.cve_id
  FROM kev_vulns k
  JOIN bounds b
    ON date(k.date_added) >= b.cutoff_month_start
)
SELECT
  vendor,
  COUNT(DISTINCT cve_id) AS cve_count_12m
FROM filtered
GROUP BY vendor
ORDER BY cve_count_12m DESC
LIMIT 10;
"""

# %%
#query top 5 vendors each month
q_top5 = """
WITH m AS (
  SELECT month_key, vendor, COUNT(DISTINCT cve_id) AS vuln_count
  FROM kev_vulns
  WHERE month_key IS NOT NULL
  GROUP BY month_key, vendor
),
r AS (
  SELECT
    m.*,
    ROW_NUMBER() OVER (PARTITION BY month_key ORDER BY vuln_count DESC, vendor) AS rk
  FROM m
)
SELECT month_key, vendor, vuln_count
FROM r
WHERE rk <= 5
ORDER BY month_key, rk;
"""

# %%
#run quries and preview results
with engine.connect() as conn:
    df_trend = pd.read_sql(text(q_trend_rolling), conn)
    df_top_vendor_12m = pd.read_sql(text(q_top_vendor_12m), conn)
    df_trend_vendor = pd.read_sql(text(q_trend_by_vendor), conn)
    df_top5 = pd.read_sql(text(q_top5), conn)

print("Ran SQL queries successfully.")
print("\n Monthly trend + rolling 6M (head):")
print(df_trend.head(10).to_string(index=False))

print("\n Top vendors (last 12 months):")
print(df_top_vendor_12m.to_string(index=False))

print("\n Trend by vendor (head):")
print(df_trend_vendor.head(10).to_string(index=False))

print("\n Top 5 vendors each month :")
print(df_top5.to_string(index=False))
# Out:
# Ran SQL queries successfully.
#
#  Monthly trend + rolling 6M (head):
# month_key  vuln_count  rolling_6m
#   2021-11         291         291
#   2021-12          20         311
#   2022-01          40         351
#   2022-02          32         383
#   2022-03         226         609
#   2022-04          45         654
#   2022-05          83         446
#   2022-06          48         474
#   2022-07           3         437
#   2022-08          23         428
#
#  Top vendors (last 12 months):
#    vendor  cve_count_12m
# Microsoft             39
#     Apple              9
#  Fortinet              8
#     Cisco              7
#    Google              7
#    Ivanti              7
#     Linux              7
#    Citrix              5
#    D-Link              5
#    Oracle              5
#
#  Trend by vendor (head):
# month_key    vendor  vuln_count
#   2021-11 Accellion           4
#   2021-11     Adobe           5
#   2021-11   Amcrest           1
#   2021-11   Android           2
#   2021-11    Apache           9
#   2021-11     Apple          23
#   2021-11  Arcadyan           1
#   2021-11       Arm           3
#   2021-11 Atlassian           4
#   2021-11       BQE           1
#
#  Top 5 vendors each month :
# month_key             vendor  vuln_count
#   2021-11          Microsoft          82
#   2021-11              Apple          23
#   2021-11             Google          22
#   2021-11              Cisco          11
#   2021-11             Apache           9
#   2021-12             Apache           3
#   2021-12               Zoho           3
#   2021-12            Red Hat           2
#   2021-12          Embedthis           1
#   2021-12           Fortinet           1
#   2022-01          Microsoft           6
#   2022-01             Apache           4
#   2022-01             Nagios           3
#   2022-01           Fortinet           2
#   2022-01                GNU           2
#   2022-02          Microsoft          16
#   2022-02              Apple           3
#   2022-02              Adobe           2
#   2022-02             Apache           2
#   2022-02             Zabbix           2
#   2022-03          Microsoft          70
#   2022-03              Cisco          44
#   2022-03              Adobe          26
#   2022-03             Oracle          11
#   2022-03             Apache           5
#   2022-04          Microsoft          11
#   2022-04              Adobe           6
#   2022-04             VMware           3
#   2022-04              Apple           2
#   2022-04             D-Link           2
#   2022-05          Microsoft          37
#   2022-05              Apple           8
#   2022-05              Adobe           7
#   2022-05             Oracle           6
#   2022-05              Cisco           3
#   2022-06              Adobe          13
#   2022-06             Google           9
#   2022-06          Microsoft           9
#   2022-06              Apple           5
#   2022-06               QNAP           4
#   2022-07          Microsoft           2
#   2022-07          Atlassian           1
#   2022-08              Apple           3
#   2022-08          Microsoft           3
#   2022-08            Synacor           3
#   2022-08             Apache           2
#   2022-08               PEAR           2
#   2022-09          Microsoft           4
#   2022-09             D-Link           3
#   2022-09              Linux           3
#   2022-09              Apple           2
#   2022-09            Android           1
#   2022-10           GIGABYTE           4
#   2022-10              Cisco           2
#   2022-10              Apple           1
#   2022-10           Fortinet           1
#   2022-10             Google           1
#   2022-11          Microsoft           5
#   2022-11            Samsung           3
#   2022-11             Google           1
#   2022-11             Oracle           1
#   2022-12              TIBCO           2
#   2022-12              Veeam           2
#   2022-12              Apple           1
#   2022-12             Citrix           1
#   2022-12           Fortinet           1
#   2023-01          Microsoft           2
#   2023-01                CWP           1
#   2023-01            Telerik           1
#   2023-01               Zoho           1
#   2023-02          Microsoft           3
#   2023-02              Mitel           2
#   2023-02              Apple           1
#   2023-02              Cacti           1
#   2023-02             Fortra           1
#   2023-03          Microsoft           3
#   2023-03                Arm           2
#   2023-03             Fortra           2
#   2023-03              Adobe           1
#   2023-03             Apache           1
#   2023-04              Apple           3
#   2023-04            Veritas           3
#   2023-04             Google           2
#   2023-04          Microsoft           2
#   2023-04            Android           1
#   2023-05              Apple           3
#   2023-05             Apache           2
#   2023-05              Cisco           2
#   2023-05              Linux           2
#   2023-05             Oracle           2
#   2023-06            Samsung           6
#   2023-06              Apple           3
#   2023-06          Roundcube           3
#   2023-06              Zyxel           3
#   2023-06             D-Link           2
#   2023-07          Microsoft           5
#   2023-07              Adobe           2
#   2023-07              Apple           2
#   2023-07             Ivanti           2
#   2023-07                Arm           1
#   2023-08              Adobe           1
#   2023-08             Citrix           1
#   2023-08    Ignite Realtime           1
#   2023-08             Ivanti           1
#   2023-08          Microsoft           1
#   2023-09              Apple           5
#   2023-09          Microsoft           2
#   2023-09              Adobe           1
#   2023-09            Android           1
#   2023-09             Apache           1
#   2023-10              Cisco           3
#   2023-10          Microsoft           3
#   2023-10                 F5           2
#   2023-10              Adobe           1
#   2023-10              Apple           1
#   2023-11            Juniper           5
#   2023-11          Microsoft           4
#   2023-11             Apache           1
#   2023-11          Atlassian           1
#   2023-11                GNU           1
#   2023-12           Qualcomm           4
#   2023-12              Apple           2
#   2023-12               Qlik           2
#   2023-12                FXC           1
#   2023-12               QNAP           1
#   2024-01             Ivanti           4
#   2024-01              Apple           3
#   2024-01              Adobe           2
#   2024-01             Citrix           2
#   2024-01             Google           2
#   2024-02          Microsoft           4
#   2024-02              Cisco           1
#   2024-02        ConnectWise           1
#   2024-02           Fortinet           1
#   2024-02             Google           1
#   2024-03              Apple           2
#   2024-03          Microsoft           2
#   2024-03            Android           1
#   2024-03           Fortinet           1
#   2024-03             Ivanti           1
#   2024-04            Android           2
#   2024-04              Cisco           2
#   2024-04             D-Link           2
#   2024-04          Microsoft           2
#   2024-04           CrushFTP           1
#   2024-05             Google           4
#   2024-05             D-Link           2
#   2024-05          Microsoft           2
#   2024-05             Apache           1
#   2024-05        Check Point           1
#   2024-06            Android           1
#   2024-06                Arm           1
#   2024-06              Linux           1
#   2024-06          Microsoft           1
#   2024-06              OSGeo           1
#   2024-07          Microsoft           3
#   2024-07         ServiceNow           2
#   2024-07             VMware           2
#   2024-07            Acronis           1
#   2024-07              Adobe           1
#   2024-08          Microsoft           8
#   2024-08             Apache           2
#   2024-08              Dahua           2
#   2024-08             Google           2
#   2024-08            Android           1
#   2024-09          Microsoft           5
#   2024-09              Adobe           4
#   2024-09            DrayTek           3
#   2024-09             Ivanti           3
#   2024-09             Oracle           2
#   2024-10          Microsoft           4
#   2024-10             Ivanti           3
#   2024-10           Fortinet           2
#   2024-10              Cisco           1
#   2024-10            Mozilla           1
#   2024-11 Palo Alto Networks           5
#   2024-11              Apple           2
#   2024-11          Microsoft           2
#   2024-11          PTZOptics           2
#   2024-11             VMware           2
#   2024-12               Cleo           2
#   2024-12          Microsoft           2
#   2024-12               NUUO           2
#   2024-12            Reolink           2
#   2024-12    Acclaim Systems           1
#   2025-01          Microsoft           3
#   2025-01              Mitel           2
#   2025-01              Apple           1
#   2025-01           Aviatrix           1
#   2025-01        BeyondTrust           1
#   2025-02          Microsoft           6
#   2025-02           Paessler           2
#   2025-02 Palo Alto Networks           2
#   2025-02             Sophos           2
#   2025-02              Zyxel           2
#   2025-03          Microsoft           7
#   2025-03             Ivanti           3
#   2025-03             VMware           3
#   2025-03          Advantive           2
#   2025-03              Cisco           2
#   2025-04              Apple           2
#   2025-04              Linux           2
#   2025-04          Microsoft           2
#   2025-04             Apache           1
#   2025-04           Broadcom           1
#   2025-05          Microsoft           5
#   2025-05          GeoVision           2
#   2025-05             Ivanti           2
#   2025-05             Apache           1
#   2025-05          Commvault           1
#   2025-06           Qualcomm           3
#   2025-06               ASUS           2
#   2025-06          Craft CMS           2
#   2025-06                AMI           1
#   2025-06              Apple           1
#   2025-07          Microsoft           3
#   2025-07              Cisco           2
#   2025-07             Google           2
#   2025-07             SysAid           2
#   2025-07        TeleMessage           2
#   2025-08             Citrix           3
#   2025-08             D-Link           3
#   2025-08          Microsoft           2
#   2025-08             N-able           2
#   2025-08              Apple           1
#   2025-09              Cisco           3
#   2025-09            TP-Link           3
#   2025-09            Adminer           1
#   2025-09            Android           1
#   2025-09  Dassault Systèmes           1
#   2025-10          Microsoft           8
#   2025-10              Adobe           2
#   2025-10  Dassault Systèmes           2
#   2025-10            Kentico           2
#   2025-10             Oracle           2
#   2025-11           Fortinet           2
#   2025-11           Gladinet           2
#   2025-11                CWP           1
#   2025-11             Google           1
#   2025-11          Microsoft           1
#   2025-12            Android           2
#   2025-12              Apple           1
#   2025-12     Array Networks           1
#   2025-12             D-Link           1
#   2025-12           Fortinet           1

# %%
#save key SQLs to file
os.makedirs("exports", exist_ok=True)
sql_bundle = f"""-- risk_queries.sql (generated)
-- 1) Monthly trend + rolling 6M
{q_trend_rolling}

-- 2) Top Vendor in last 12 months
{q_top_vendor_12m}

-- 3) Monthly trend by vendor
{q_trend_by_vendor}

-- 4) Top 5 vendors each month
{q_top5}

"""
with open("exports/risk_queries.sql", "w", encoding="utf-8") as f:
    f.write(sql_bundle)

print("\n[SUMMARY] Saved queries to: exports/risk_queries.sql")
print(
    f"[CHECK] Trend rows: {len(df_trend):,} | "
    f"Trend-by-vendor rows: {len(df_trend_vendor):,} | "
    f"Top vendors rows: {len(df_top_vendor_12m):,} | "
    f"Top 5 vendors each month rows: {len(df_top5):,}"
)
# Out:
# [SUMMARY] Saved queries to: exports/risk_queries.sql
# [CHECK] Trend rows: 50 | Trend-by-vendor rows: 689 | Top vendors rows: 10 | Top 5 vendors each month rows: 245

# %%
#ดึงคะแนน CVSS จริงจาก NVD API
import requests, time, os, pandas as pd

NVD_API_KEY = os.getenv("NVD_API_KEY", "")
NVD_BASE = "https://services.nvd.nist.gov/rest/json/cves/2.0"

def fetch_nvd_cvss_for_batch(cve_ids):
    if not cve_ids:
        return {}

    params = [("cveId", cid) for cid in cve_ids]
    headers = {"apiKey": NVD_API_KEY} if NVD_API_KEY else {}

    r = requests.get(NVD_BASE, params=params, headers=headers, timeout=60)
    if r.status_code in (429, 502, 503):
        time.sleep(5)
        r = requests.get(NVD_BASE, params=params, headers=headers, timeout=60)

    r.raise_for_status()
    data = r.json()

    out = {}
    for item in data.get("vulnerabilities", []):
        cve_id = item["cve"]["id"]
        metrics = item["cve"].get("metrics", {})
        cvss = severity = vector = None

        for key in ("cvssMetricV31","cvssMetricV30","cvssMetricV2"):
            if key in metrics:
                m = metrics[key][0].get("cvssData", {})
                cvss = m.get("baseScore")
                severity = m.get("baseSeverity")
                vector = m.get("vectorString")
                break

        out[cve_id] = {"cvss": cvss, "severity": severity, "vector": vector}

    return out

# %%
def fetch_nvd_cvss_all(cve_ids, batch_size=100, pause_no_key=1.1, pause_with_key=0.2):
    """แตกเป็น batch เพื่อเลี่ยง rate limit"""
    mapping = {}
    total = len(cve_ids)
    for i in range(0, total, batch_size):
        batch = cve_ids[i:i+batch_size]
        try:
            res = fetch_nvd_cvss_for_batch(batch)
            mapping.update(res)
            print(f"[NVD] batch {i//batch_size+1}: fetched {len(res)}/{len(batch)}")
        except Exception as e:
            print(f"[WARN] batch {i//batch_size+1} failed: {e}")
        time.sleep(pause_with_key if NVD_API_KEY else pause_no_key)
    return mapping

# %%
#เตรียมการคำนวณ exposure score
import pandas as pd
import numpy as np
from datetime import datetime, timezone

#เตรียมคอลัมน์วันที่สำหรับคำนวณอายุช่องโหว่
df_expo = df.copy()
#แปลงให้เป็น datetime
df_expo["date_added"] = pd.to_datetime(df_expo["date_added"], errors="coerce", utc=True)

# %%
#ดึง CVSS จริง + รวมเข้ากับ df_expo
           .reset_index().rename(columns={"index":"cve_id"}))

# %%
#คำนวณอายุช่องโหว่
as_of = df_expo["date_added"].max()
df_expo["age_days"] = (as_of - df_expo["date_added"]).dt.days

# %%
#คำนวณ decay factor
HALF_LIFE = 180.0
df_expo["decay"] = np.power(0.5, df_expo["age_days"] / HALF_LIFE)

# %%
#merge เข้ากับ df_expo
df_expo["cve_id"] = df_expo["cve_id"].astype(str).str.upper().str.strip()
df_expo = df_expo.merge(cvss_df, on="cve_id", how="left")

# %%
#เติมค่า default เพื่อไม่ให้หลุดการคำนวณ
#df_expo["cvss"] = pd.to_numeric(df_expo["cvss"], errors="coerce").fillna(7.5)

# จำลองข้อมูล CVSS
print("Simulated Data เพื่อเลี่ยง NVD API Error")

np.random.seed(42) # กำหนดผลให้เหมือนเดิมทุกครั้ง

# สุ่มคะแนน 1.0 - 10.0 (เน้นค่า 7.5)
random_cvss = np.random.normal(loc=7.5, scale=1.5, size=len(df_expo))
df_expo["cvss"] = np.clip(np.round(random_cvss, 1), 1.0, 10.0)

print(f"สร้างคะแนนจำลองเรียบร้อย: {len(df_expo)} รายการ")
print(df_expo["cvss"].describe())
# Out:
# Simulated Data เพื่อเลี่ยง NVD API Error
# สร้างคะแนนจำลองเรียบร้อย: 1478 รายการ
# count    1478.000000
# mean        7.532815
# std         1.410354
# min         2.600000
# 25%         6.600000
# 50%         7.600000
# 75%         8.500000
# max        10.000000
# Name: cvss, dtype: float64

# %%
print("จำนวน CVSS ที่ดึงสำเร็จ:", df_expo[df_expo["cvss"] != 7.5].shape[0])
print("จำนวน CVSS ที่ถูก fillna:", df_expo[df_expo["cvss"] == 7.5].shape[0])
# Out:
# จำนวน CVSS ที่ดึงสำเร็จ: 1435
# จำนวน CVSS ที่ถูก fillna: 43

# %%
print("[CVSS coverage] describe():")
print(df_expo["cvss"].describe())
# Out:
# [CVSS coverage] describe():
# count    1478.000000
# mean        7.532815
# std         1.410354
# min         2.600000
# 25%         6.600000
# 50%         7.600000
# 75%         8.500000
# max        10.000000
# Name: cvss, dtype: float64

# %%
#Exposure = CVSS × decay  + สรุป + export

#คำนวณ exposure
df_expo["exposure_score"] = df_expo["cvss"] * df_expo["decay"]

# %%
#สรุปผลสำหรับ dashboard
expo_month = (
    df_expo.groupby("month_key", as_index=False)
           .agg(vuln_count=("cve_id","nunique"),
                exposure_sum=("exposure_score","sum"),
                exposure_avg=("exposure_score","mean"))
           .sort_values("month_key")
)
expo_vendor_month = (
    df_expo.groupby(["month_key","vendor"], as_index=False)
           .agg(vuln_count=("cve_id","nunique"),
                exposure_sum=("exposure_score","sum"))
           .sort_values(["month_key","exposure_sum"], ascending=[True, False])
)

print("[Preview] Monthly exposure head:")
print(expo_month.head(10).to_string(index=False))
# Out:
# [Preview] Monthly exposure head:
# month_key  vuln_count  exposure_sum  exposure_avg
#   2021-11         291      6.722764      0.023102
#   2021-12          20      0.514825      0.025741
#   2022-01          40      1.242125      0.031053
#   2022-02          32      1.135928      0.035498
#   2022-03         226      8.841478      0.039122
#   2022-04          45      1.940711      0.043127
#   2022-05          83      4.158483      0.050102
#   2022-06          48      2.541390      0.052946
#   2022-07           3      0.179211      0.059737
#   2022-08          23      1.581918      0.068779

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

#เรียงลำดับเอาคะแนนความเสี่ยงสูงสุด 10 อันดับแรก
top_risk =  df_expo.sort_values(by='exposure_score', ascending=False).head(10)

ax = sns.barplot(x='exposure_score', y='cve_id', data=top_risk, palette='magma')

plt.title('Top 10 Critical CVEs by "Exposure Score"', fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Exposure Score (Time-Decay Adjusted)', fontsize=12)
plt.ylabel('CVE ID', fontsize=12)

plt.xlim(0, 11)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f', padding=5, fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2227583090.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='exposure_score', y='cve_id', data=top_risk, palette='magma')

# %%
#export
import os
os.makedirs("exports", exist_ok=True)

cols_out = ["cve_id","vendor","product","vuln_name","date_added","due_date",
            "known_ransomware_use","cwe","cvss","age_days","decay","exposure_score","month_key"]
cols_out = [c for c in cols_out if c in df_expo.columns]
df_expo[cols_out].to_csv("exports/kev_clean_full.csv", index=False)
expo_month.to_csv("exports/kev_trend_monthly.csv", index=False)
expo_vendor_month.to_csv("exports/kev_vendor_month.csv", index=False)

print("\n[SUMMARY] Exported files:")
for p in ["exports/kev_clean_full.csv","exports/kev_trend_monthly.csv","exports/kev_vendor_month.csv"]:
    print("-", p, "| exists:", os.path.exists(p))
# Out:
# [SUMMARY] Exported files:
# - exports/kev_clean_full.csv | exists: True
# - exports/kev_trend_monthly.csv | exists: True
# - exports/kev_vendor_month.csv | exists: True

# %%
#Connect to risk.db and เตรียม exports folder
import os
import pandas as pd
from sqlalchemy import create_engine, text

os.makedirs("exports", exist_ok=True)

DB_PATH = "risk.db"
engine = create_engine(f"sqlite:///{DB_PATH}", future=True)

# ตรวจว่ามีตาราง kev_vulns จริงไหม
with engine.connect() as con:
    tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", con)
print("[CHECK] Tables in DB:")
print(tables.to_string(index=False))
# Out:
# [CHECK] Tables in DB:
#      name
# kev_vulns

# %%
#Monthly Trend + Rolling 6M
q_trend_rolling = """
WITH m AS (
  SELECT
    month_key,
    COUNT(DISTINCT cve_id) AS vuln_count
  FROM kev_vulns
  WHERE month_key IS NOT NULL
  GROUP BY month_key
)
SELECT
  month_key,
  vuln_count,
  SUM(vuln_count) OVER (
    ORDER BY month_key
    ROWS BETWEEN 5 PRECEDING AND CURRENT ROW
  ) AS rolling_6m
FROM m
ORDER BY month_key;
"""

with engine.connect() as con:
    df_trend = pd.read_sql_query(text(q_trend_rolling), con)

# export
df_trend.to_csv("exports/kev_trend_monthly.csv", index=False)

print("[OK] Saved exports/kev_trend_monthly.csv")
print(df_trend.head(10).to_string(index=False))
# Out:
# [OK] Saved exports/kev_trend_monthly.csv
# month_key  vuln_count  rolling_6m
#   2021-11         291         291
#   2021-12          20         311
#   2022-01          40         351
#   2022-02          32         383
#   2022-03         226         609
#   2022-04          45         654
#   2022-05          83         446
#   2022-06          48         474
#   2022-07           3         437
#   2022-08          23         428

# %%
#Top Vendors in last 12 months
q_top_vendor_12m = """
WITH bounds AS (
  SELECT
    date(strftime('%Y-%m-01', MAX(date_added))) AS max_month_start,
    date(strftime('%Y-%m-01', MAX(date_added)), '-11 months') AS cutoff_month_start
  FROM kev_vulns
),
filtered AS (
  SELECT k.vendor, k.cve_id
  FROM kev_vulns k
  JOIN bounds b
    ON date(k.date_added) >= b.cutoff_month_start
)
SELECT
  vendor,
  COUNT(DISTINCT cve_id) AS cve_count_12m
FROM filtered
GROUP BY vendor
ORDER BY cve_count_12m DESC
LIMIT 10;
"""

with engine.connect() as con:
    df_top = pd.read_sql_query(text(q_top_vendor_12m), con)

df_top.to_csv("exports/top_vendor_12m.csv", index=False)

print("[OK] Saved exports/top_vendor_12m.csv")
print(df_top.to_string(index=False))
# Out:
# [OK] Saved exports/top_vendor_12m.csv
#    vendor  cve_count_12m
# Microsoft             39
#     Apple              9
#  Fortinet              8
#     Cisco              7
#    Google              7
#    Ivanti              7
#     Linux              7
#    Citrix              5
#    D-Link              5
#    Oracle              5

# %%
#save highlight SQLs into risk_queries.sql
queries_path = "risk_queries.sql"

with open(queries_path, "w", encoding="utf-8") as f:
    f.write("-- Trend + Rolling 6M\n")
    f.write(q_trend_rolling.strip() + ";\n\n")
    f.write("-- Top Vendors in Last 12 Months\n")
    f.write(q_top_vendor_12m.strip() + ";\n")

print("[OK] risk_queries.sql created")
# Out:
# [OK] risk_queries.sql created

# %%
#Check final outputs
need = [
    "exports/kev_clean_full.csv",
    "exports/kev_trend_monthly.csv",
    "exports/top_vendor_12m.csv",
    "exports/kev_vendor_month.csv",
    "risk.db",
    "risk_queries.sql"
]

for p in need:
    print(f"{p:<35} exists: {os.path.exists(p)}")
# Out:
# exports/kev_clean_full.csv          exists: True
# exports/kev_trend_monthly.csv       exists: True
# exports/top_vendor_12m.csv          exists: True
# exports/kev_vendor_month.csv        exists: True
# risk.db                             exists: True
# risk_queries.sql                    exists: True

# %%
import pandas as pd
from google.colab import data_table

data_table.enable_dataframe_formatter()  #interactive table

files = [
    "exports/kev_clean_full.csv",
    "exports/kev_trend_monthly.csv",
    "exports/top_vendor_12m.csv",
    "exports/kev_vendor_month.csv"
]

for f in files:
    print("Preview of:", f)
    try:
        df = pd.read_csv(f)
        display(df.head(20))
    except Exception as e:
        print(f"ไม่สามารถเปิดไฟล์ {f} ได้ :", e)
# Out:
# Preview of: exports/kev_clean_full.csv
#             cve_id           vendor                  product  \
# 0   CVE-2025-59718         Fortinet        Multiple Products
# 1   CVE-2025-14611         Gladinet  CentreStack and Triofox
# 2   CVE-2025-43529            Apple        Multiple Products
# 3    CVE-2018-4063  Sierra Wireless            AirLink ALEOS
# 4   CVE-2025-14174           Google                 Chromium
# 5   CVE-2025-58360            OSGeo                GeoServer
# 6    CVE-2025-6218           RARLAB                   WinRAR
# 7   CVE-2025-62221        Microsoft                  Windows
# 8   CVE-2022-37055           D-Link                  Routers
# 9   CVE-2025-66644   Array Networks               ArrayOS AG
# 10  CVE-2025-55182             Meta  React Server Components
# 11  CVE-2021-26828          OpenPLC                  ScadaBR
# 12  CVE-2025-48633          Android                Framework
# 13  CVE-2025-48572          Android                Framework
# 14  CVE-2021-26829          OpenPLC                  ScadaBR
# 15  CVE-2025-61757           Oracle        Fusion Middleware
# 16  CVE-2025-13223           Google              Chromium V8
# 17  CVE-2025-58034         Fortinet                 FortiWeb
# 18  CVE-2025-64446         Fortinet                 FortiWeb
# 19  CVE-2025-12480         Gladinet                  Triofox
#
#                                             vuln_name  \
# 0   Fortinet Multiple Products Improper Verificati...
# 1   Gladinet CentreStack and Triofox Hard Coded Cr...
# 2   Apple Multiple Products Use-After-Free WebKit ...
# 3   Sierra Wireless AirLink ALEOS Unrestricted Upl...
# 4   Google Chromium Out of Bounds Memory Access Vu...
# 5   OSGeo GeoServer Improper Restriction of XML Ex...
# 6          RARLAB WinRAR Path Traversal Vulnerability
# 7      Microsoft Windows Use After Free Vulnerability
# 8        D-Link Routers Buffer Overflow Vulnerability
# 9   Array Networks ArrayOS AG OS Command Injection...
# 10  Meta React Server Components Remote Code Execu...
# 11  OpenPLC ScadaBR Unrestricted Upload of File wi...
# 12  Android Framework Information Disclosure Vulne...
# 13  Android Framework Privilege Escalation Vulnera...
# 14  OpenPLC ScadaBR Cross-site Scripting Vulnerabi...
# 15  Oracle Fusion Middleware Missing Authenticatio...
# 16    Google Chromium V8 Type Confusion Vulnerability
# 17  Fortinet FortiWeb OS Command Injection Vulnera...
# 18     Fortinet FortiWeb Path Traversal Vulnerability
# 19  Gladinet Triofox Improper Access Control Vulne...
#
#                    date_added                   due_date known_ransomware_use  \
# 0   2025-12-16 00:00:00+00:00  2025-12-23 00:00:00+00:00              Unknown
# 1   2025-12-15 00:00:00+00:00  2026-01-05 00:00:00+00:00              Unknown
# 2   2025-12-15 00:00:00+00:00  2026-01-05 00:00:00+00:00              Unknown
# 3   2025-12-12 00:00:00+00:00  2026-01-02 00:00:00+00:00              Unknown
# 4   2025-12-12 00:00:00+00:00  2026-01-02 00:00:00+00:00              Unknown
# 5   2025-12-11 00:00:00+00:00  2026-01-01 00:00:00+00:00              Unknown
# 6   2025-12-09 00:00:00+00:00  2025-12-30 00:00:00+00:00              Unknown
# 7   2025-12-09 00:00:00+00:00  2025-12-30 00:00:00+00:00              Unknown
# 8   2025-12-08 00:00:00+00:00  2025-12-29 00:00:00+00:00              Unknown
# 9   2025-12-08 00:00:00+00:00  2025-12-29 00:00:00+00:00              Unknown
# 10  2025-12-05 00:00:00+00:00  2025-12-12 00:00:00+00:00                Known
# 11  2025-12-03 00:00:00+00:00  2025-12-24 00:00:00+00:00              Unknown
# 12  2025-12-02 00:00:00+00:00  2025-12-23 00:00:00+00:00              Unknown
# 13  2025-12-02 00:00:00+00:00  2025-12-23 00:00:00+00:00              Unknown
# 14  2025-11-28 00:00:00+00:00  2025-12-19 00:00:00+00:00              Unknown
# 15  2025-11-21 00:00:00+00:00  2025-12-12 00:00:00+00:00              Unknown
# 16  2025-11-19 00:00:00+00:00  2025-12-10 00:00:00+00:00              Unknown
# 17  2025-11-18 00:00:00+00:00  2025-11-25 00:00:00+00:00              Unknown
# 18  2025-11-14 00:00:00+00:00  2025-11-21 00:00:00+00:00              Unknown
# 19  2025-11-12 00:00:00+00:00  2025-12-03 00:00:00+00:00              Unknown
#
#         cwe  cvss  age_days     decay  exposure_score month_key
# 0   CWE-347   8.2         0  1.000000        8.200000   2025-12
# 1   CWE-798   7.3         1  0.996157        7.271943   2025-12
# 2   CWE-416   8.5         1  0.996157        8.467331   2025-12
# 3   CWE-434   9.8         4  0.984715        9.650205   2025-12
# 4   Unknown   7.1         4  0.984715        6.991475   2025-12
# 5   CWE-611   7.1         5  0.980930        6.964604   2025-12
# 6    CWE-22   9.9         7  0.973404        9.636703   2025-12
# 7   CWE-416   8.7         7  0.973404        8.468618   2025-12
# 8   CWE-120   6.8         8  0.969663        6.593709   2025-12
# 9    CWE-78   8.3         8  0.969663        8.048204   2025-12
# 10  Unknown   6.8        11  0.958526        6.517974   2025-12
# 11  CWE-434   6.8        13  0.951172        6.467968   2025-12
# 12  Unknown   7.9        14  0.947516        7.485376   2025-12
# 13  Unknown   4.6        14  0.947516        4.358574   2025-12
# 14   CWE-79   4.9        18  0.933033        4.571862   2025-11
# 15  CWE-306   6.7        25  0.908218        6.085063   2025-11
# 16  CWE-843   6.0        27  0.901250        5.407503   2025-11
# 17   CWE-78   8.0        28  0.897787        7.182293   2025-11
# 18   CWE-23   6.1        32  0.884064        5.392789   2025-11
# 19  CWE-284   5.4        34  0.877281        4.737318   2025-11
# Preview of: exports/kev_trend_monthly.csv
#    month_key  vuln_count  rolling_6m
# 0    2021-11         291         291
# 1    2021-12          20         311
# 2    2022-01          40         351
# 3    2022-02          32         383
# 4    2022-03         226         609
# 5    2022-04          45         654
# 6    2022-05          83         446
# 7    2022-06          48         474
# 8    2022-07           3         437
# 9    2022-08          23         428
# 10   2022-09          24         226
# 11   2022-10          12         193
# 12   2022-11          10         120
# 13   2022-12           9          81
# 14   2023-01           5          83
# 15   2023-02          14          74
# 16   2023-03          18          68
# 17   2023-04          17          73
# 18   2023-05          19          82
# 19   2023-06          24          97
# Preview of: exports/top_vendor_12m.csv
#       vendor  cve_count_12m
# 0  Microsoft             39
# 1      Apple              9
# 2   Fortinet              8
# 3      Cisco              7
# 4     Google              7
# 5     Ivanti              7
# 6      Linux              7
# 7     Citrix              5
# 8     D-Link              5
# 9     Oracle              5
# Preview of: exports/kev_vendor_month.csv
#    month_key       vendor  vuln_count  exposure_sum
# 0    2021-11    Microsoft          82      1.851703
# 1    2021-11        Apple          23      0.550456
# 2    2021-11       Google          22      0.501303
# 3    2021-11        Cisco          11      0.235386
# 4    2021-11       Ivanti           9      0.227754
# 5    2021-11       Apache           9      0.189286
# 6    2021-11       VMware           8      0.184401
# 7    2021-11  Trend Micro           7      0.176158
# 8    2021-11       Oracle           7      0.164862
# 9    2021-11       Citrix           6      0.145934
# 10   2021-11    SonicWall           5      0.127310
# 11   2021-11        Adobe           5      0.126089
# 12   2021-11          SAP           6      0.123952
# 13   2021-11          IBM           4      0.085789
# 14   2021-11    Atlassian           4      0.081515
# 15   2021-11    Accellion           4      0.076936
# 16   2021-11          Arm           3      0.076325
# 17   2021-11   SolarWinds           3      0.073577
# 18   2021-11    WordPress           3      0.070830
# 19   2021-11     Fortinet           3      0.069914
